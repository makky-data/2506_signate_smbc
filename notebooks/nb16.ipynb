# %% [markdown]
# # CatBoost検討用nb

# %% [markdown]
# ## Mount＆modjule import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 目的：スペインの電力価格を予測
# 目的変数：スペインの電力価格(actual_price)
# 評価指標：RME

import numpy as np
import pandas as pd
import os
import pickle
import gc
# 分布確認
# !pip install ydata-profiling
from ydata_profiling import ProfileReport
# 可視化
import matplotlib.pyplot as plt
import seaborn as sns
import polars as pl
# 前処理
from sklearn.preprocessing import StandardScaler, MinMaxScaler,LabelEncoder,OneHotEncoder
# モデリング
from sklearn.model_selection import train_test_split,KFold,StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from xgboost import XGBClassifier
import lightgbm as lgb
import xgboost as xgb
# !pip install -U xgboost -q
# !pip install -q catboost
from catboost import CatBoostRegressor, Pool

# 日本語表記
# !pip install japanize-matplotlib
import japanize_matplotlib
# %matplotlib inline
# パラメータ最適化
# !pip install optuna
import optuna

# 評価指標
from sklearn.metrics import mean_squared_error
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.11.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.0.2)
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.4.3)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.9.4)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.6.15)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-1.29-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 8.0 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 21.8 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (687 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 26.9 MB/s eta 0:00:00
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.1 MB/s eta 0:00:00
# Downloading puremagic-1.29-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.0 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=7ffc811d1568d03be24119c2960945a2b4d6bf9ad057d61dda8324c646132646
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: puremagic, htmlmin, multimethod, dacite, imagehash, visions, phik, ydata-profiling
# Successfully installed dacite-1.9.2 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.12 phik-0.12.4 puremagic-1.29 visions-0.8.1 ydata-profiling-4.16.1
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.6 MB/s eta 0:00:00
# Collecting japanize-matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 33.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from japanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize-matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize-matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize-matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize-matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize-matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize-matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize-matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->japanize-matplotlib) (1.17.0)
# Building wheels for collected packages: japanize-matplotlib
#   Building wheel for japanize-matplotlib (setup.py) ... done
#   Created wheel for japanize-matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=8da080e1421fbc57fa81cf02fd1280cfd33e1447d96bd4d61e6f7970e35640a6
#   Stored in directory: /root/.cache/pip/wheels/da/a1/71/b8faeb93276fed10edffcca20746f1ef6f8d9e071eee8425fc
# Successfully built japanize-matplotlib
# Installing collected packages: japanize-matplotlib
# Successfully installed japanize-matplotlib-1.1.3
# Collecting optuna
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 7.7 MB/s eta 0:00:00
# Downloading alembic-1.16.2-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 17.0 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.2 colorlog-6.9.0 optuna-4.4.0

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/signate/smbc/'

df_train = pd.read_csv(file_path + 'train.csv')
df_test = pd.read_csv(file_path + 'test.csv')

# %%
print("train_shape:",df_train.shape)
display(df_train.head())
print("test_shape:",df_test.shape)
display(df_test.head())
# Out:
# train_shape: (26280, 92)
#                         time  generation_biomass  \
# 0  2015-01-02 00:00:00+01:00               447.0
# 1  2015-01-02 01:00:00+01:00               449.0
# 2  2015-01-02 02:00:00+01:00               448.0
# 3  2015-01-02 03:00:00+01:00               438.0
# 4  2015-01-02 04:00:00+01:00               428.0
#
#    generation_fossil_brown_coal/lignite  generation_fossil_gas  \
# 0                                 329.0                 4844.0
# 1                                 328.0                 5196.0
# 2                                 323.0                 4857.0
# 3                                 254.0                 4314.0
# 4                                 187.0                 4130.0
#
#    generation_fossil_hard_coal  generation_fossil_oil  \
# 0                       4821.0                  162.0
# 1                       4755.0                  158.0
# 2                       4581.0                  157.0
# 3                       4131.0                  160.0
# 4                       3840.0                  156.0
#
#    generation_hydro_pumped_storage_consumption  \
# 0                                        863.0
# 1                                        920.0
# 2                                       1164.0
# 3                                       1503.0
# 4                                       1826.0
#
#    generation_hydro_run_of_river_and_poundage  \
# 0                                      1051.0
# 1                                      1009.0
# 2                                       973.0
# 3                                       949.0
# 4                                       953.0
#
#    generation_hydro_water_reservoir  generation_nuclear  ...  \
# 0                            1899.0              7096.0  ...
# 1                            1658.0              7096.0  ...
# 2                            1371.0              7099.0  ...
# 3                             779.0              7098.0  ...
# 4                             720.0              7097.0  ...
#
#    seville_wind_deg  seville_rain_1h  seville_rain_3h  seville_snow_3h  \
# 0                33              0.0              0.0              0.0
# 1                33              0.0              0.0              0.0
# 2                44              0.0              0.0              0.0
# 3                44              0.0              0.0              0.0
# 4                44              0.0              0.0              0.0
#
#    seville_clouds_all  seville_weather_id  seville_weather_main  \
# 0                   0                 800                 clear
# 1                   0                 800                 clear
# 2                   0                 800                 clear
# 3                   0                 800                 clear
# 4                   0                 800                 clear
#
#    seville_weather_description  seville_weather_icon  price_actual
# 0                 sky is clear                   01n         64.02
# 1                 sky is clear                   01n         58.46
# 2                 sky is clear                   01n         54.70
# 3                 sky is clear                   01n         54.91
# 4                 sky is clear                   01n         53.07
#
# [5 rows x 92 columns]
# test_shape: (8760, 91)
#                         time  generation_biomass  \
# 0  2018-01-01 00:00:00+01:00               279.0
# 1  2018-01-01 01:00:00+01:00               282.0
# 2  2018-01-01 02:00:00+01:00               283.0
# 3  2018-01-01 03:00:00+01:00               280.0
# 4  2018-01-01 04:00:00+01:00               286.0
#
#    generation_fossil_brown_coal/lignite  generation_fossil_gas  \
# 0                                   0.0                 3927.0
# 1                                   0.0                 3948.0
# 2                                   0.0                 3791.0
# 3                                   0.0                 3671.0
# 4                                   0.0                 3460.0
#
#    generation_fossil_hard_coal  generation_fossil_oil  \
# 0                        895.0                  189.0
# 1                        878.0                  177.0
# 2                        890.0                  175.0
# 3                        881.0                  175.0
# 4                        861.0                  173.0
#
#    generation_hydro_pumped_storage_consumption  \
# 0                                        230.0
# 1                                       1269.0
# 2                                       2197.0
# 3                                       2965.0
# 4                                       2705.0
#
#    generation_hydro_run_of_river_and_poundage  \
# 0                                      1069.0
# 1                                      1058.0
# 2                                      1052.0
# 3                                      1032.0
# 4                                      1001.0
#
#    generation_hydro_water_reservoir  generation_nuclear  ...  \
# 0                            1893.0              7104.0  ...
# 1                            1024.0              7101.0  ...
# 2                             888.0              7100.0  ...
# 3                             645.0              7101.0  ...
# 4                             661.0              7101.0  ...
#
#    seville_wind_speed  seville_wind_deg  seville_rain_1h  seville_rain_3h  \
# 0                   1               343              0.0              0.0
# 1                   1               343              0.0              0.0
# 2                   1                 0              0.0              0.0
# 3                   1                40              0.0              0.0
# 4                   1                30              0.0              0.0
#
#    seville_snow_3h  seville_clouds_all  seville_weather_id  \
# 0              0.0                   0                 800
# 1              0.0                   0                 800
# 2              0.0                   0                 800
# 3              0.0                   0                 800
# 4              0.0                   0                 800
#
#    seville_weather_main  seville_weather_description  seville_weather_icon
# 0                 clear                 sky is clear                   01n
# 1                 clear                 sky is clear                   01n
# 2                 clear                 sky is clear                   01n
# 3                 clear                 sky is clear                   01n
# 4                 clear                 sky is clear                   01n
#
# [5 rows x 91 columns]

# %% [markdown]
# ## 前処理

# %%
# 時刻をdatetimeに変換
df_train["time"] = pd.to_datetime(df_train["time"],utc=True)
df_test["time"] = pd.to_datetime(df_test["time"],utc=True)

# 年情報のカラム作成（クロスバリデーション用）
df_train["year"] = df_train["time"].dt.year
df_test["year"] = df_test["time"].dt.year

# ケルビンを摂氏に変換  - 273.15
cities = ["valencia","madrid","bilbao","barcelona","seville"]
temp_cols = [f"{c}_{t}" for c in cities for t in ["temp", "temp_min", "temp_max"]]

for df in (df_train, df_test):          # ★ 2 つとも回す
    for col in temp_cols:
        df[col] = df[col] - 273.15

print("train temp range :", df_train["seville_temp_min"].min(), df_train["seville_temp_min"].max())
print("test  temp range :", df_test ["seville_temp_min"].min(), df_test ["seville_temp_min"].max())
# Out:
# train temp range : -4.0 42.0
# test  temp range : -3.0 42.0

# %% [markdown]
# ## 特徴量エンジニアリング

# %%
# 季節性（spring:1,summer:2,autumn:3,winter:4）
def get_season(month):
    if month in [3, 4, 5]:
        return 1
    elif month in [6, 7, 8]:
        return 2
    elif month in [9, 10, 11]:
        return 3
    else:
        return 4

# 月を取得 → 季節に変換
df_train["month"] = df_train["time"].dt.month
df_train["season"] = df_train["month"].apply(get_season)

# テストデータにも
df_test["month"] = df_test["time"].dt.month
df_test["season"] = df_test["month"].apply(get_season)

# %%
# 時間帯（morning:1,afternoon:2,evening:3,night:4）

def get_time_of_day(hour):
    if 5 <= hour < 11:
        return 1
    elif 11 <= hour < 17:
        return 2
    elif 17 <= hour < 21:
        return 3
    else:
        return 4

df_train["hour"] = df_train["time"].dt.hour
df_train["time_of_day"] = df_train["hour"].apply(get_time_of_day)

# テストデータにも
df_test["hour"] = df_test["time"].dt.hour
df_test["time_of_day"] = df_test["hour"].apply(get_time_of_day)

# %%
# 時間帯：夜とそれ以外（night:1,others:0）

def get_time_of_day_only_night(hour):
    if 5 <= hour < 21:
        return 0
    else:
        return 1

df_train["hour"] = df_train["time"].dt.hour
df_train["time_of_day_only_night"] = df_train["hour"].apply(get_time_of_day)

# テストデータにも
df_test["hour"] = df_test["time"].dt.hour
df_test["time_of_day_only_night"] = df_test["hour"].apply(get_time_of_day)

# %%
# 週末フラグ

def is_week_end(weekday):
    if weekday in [0,1,2,3,4]:
      return 0
    elif weekday in [5,6]:
      return 1
    else:
      return 2

df_train["weekday"] = df_train["time"].dt.weekday
df_train["is_weekend"] = df_train["weekday"].apply(is_week_end)

# テストデータにも
df_test["weekday"] = df_test["time"].dt.weekday
df_test["is_weekend"] = df_test["weekday"].apply(is_week_end)

# %%
# 発電量の和
generation_columns = [col for col in df_train.columns if 'generation' in col]
df_train['generation_sum'] = df_train[generation_columns].sum(axis=1)
df_test['generation_sum'] = df_test[generation_columns].sum(axis=1)

# %%
# 発電量のうちの火力発電の構成比[fossil]再生可能エネルギー構成比[renewable]
df_train['generation_sum'] = df_train[generation_columns].sum(axis=1)
df_test['generation_sum'] = df_test[generation_columns].sum(axis=1)

# --- ② 分子になる電源グループ ---
df_train["fossil_total"]     = (
        df_train["generation_fossil_gas"]
      + df_train["generation_fossil_hard_coal"]
      + df_train["generation_fossil_oil"]
)
df_test["fossil_total"]      = (
        df_test["generation_fossil_gas"]
      + df_test["generation_fossil_hard_coal"]
      + df_test["generation_fossil_oil"]
)

df_train["renewable_total"]  = (
        df_train["generation_hydro_pumped_storage_consumption"]
      + df_train["generation_hydro_run_of_river_and_poundage"]
      + df_train["generation_hydro_water_reservoir"]
      + df_train["generation_other_renewable"]
)
df_test["renewable_total"]   = (
        df_test["generation_hydro_pumped_storage_consumption"]
      + df_test["generation_hydro_run_of_river_and_poundage"]
      + df_test["generation_hydro_water_reservoir"]
      + df_test["generation_other_renewable"]
)

# --- ③ 比率を安全に計算（0 除算防止） ---
eps = 1e-6
df_train["fossil_share"]     = df_train["fossil_total"]    / (df_train["generation_sum"] + eps)
df_test["fossil_share"]      = df_test["fossil_total"]     / (df_test["generation_sum"]  + eps)

df_train["renewable_share"]  = df_train["renewable_total"] / (df_train["generation_sum"] + eps)
df_test["renewable_share"]   = df_test["renewable_total"]  / (df_test["generation_sum"]  + eps)

# %%
# 祝日と3連休
import holidays, numpy as np

es_holidays = holidays.Spain(years=[2015, 2016, 2017, 2018])

for df in (df_train, df_test):
    df["is_holiday"] = df["time"].dt.date.map(lambda d: 1 if d in es_holidays else 0)
    # 前後1日
    for s in [-1, 1]:
        df[f"hol_adj{s}"] = df["is_holiday"].shift(s).fillna(0)
    # 3連休以上を flag
    df["is_long_wend"] = (
        (df["is_holiday"].rolling(3, min_periods=1).sum() >= 2).astype(int)
    )

# %%
# ---------------------------目的変数との相関が-0.24あったバレンシアの気温差---------------------------
# valencia_temp_diff
df_train["valencia_temp_diff"] = df_train["valencia_temp_max"] - df_train["valencia_temp_min"]
df_test["valencia_temp_diff"] = df_test["valencia_temp_max"] - df_test["valencia_temp_min"]

# %%
# ---------------------------チュートリアルにあった快適気温との差(valenciaのみ)---------------------------
# temp_dev
COMFORT = 23.0
df_train["temp_dev"] = (df_train["valencia_temp"] - COMFORT).abs()
df_test["temp_dev"] = (df_test["valencia_temp"] - COMFORT).abs()

# 不快指数

# %%
# ---------------------------交差項---------------------------
# season×is_weekend
df_train["season_isweekend"] = df_train["season"] * df_train["is_weekend"]
df_test["season_isweekend"] = df_test["season"] * df_test["is_weekend"]

# time_of_day×is_weekend
df_train["time_of_day_isweekend"] = df_train["time_of_day"] * df_train["is_weekend"]
df_test["time_of_day_isweekend"] = df_test["time_of_day"] * df_test["is_weekend"]

# %%
# --------------------- fossil_shareやrenewable_shareの変化量：風・太陽が落ちると火力比率↑ → 価格急騰。---------------------------------
# fossil_share_diff1
# renewable_share_diff1
# fossil_share_dev7d
# renewable_share_dev7d
share_cols = ["fossil_share", "renewable_share"]

for df in (df_train, df_test):
    # ---- ① 1 時間前との差分 ----
    for col in share_cols:
        df[f"{col}_diff1"] = df[col] - df[col].shift(1)

    # ---- ② 7日(168h) 移動平均からのずれ ----
    window = 24*7       # 168
    for col in share_cols:
        roll_mean = df[col].rolling(window, min_periods=1).mean()
        df[f"{col}_dev7d"] = df[col] - roll_mean

# %%
# ---------------------------price actualのラグ特徴量---------------------------
# ステップ 1：時系列順にソート
df_train = df_train.sort_values("time").reset_index(drop=True)
df_test = df_test.sort_values("time").reset_index(drop=True)

# ステップ 2：df_train にラグ追加（shift）
df_train["price_actual_lag1"]   = df_train["price_actual"].shift(1)
df_train["price_actual_lag24"]  = df_train["price_actual"].shift(24)
df_train["price_actual_lag168"] = df_train["price_actual"].shift(168)

# NaNを含む行を除外（df_train のみ）
df_train = df_train.dropna(subset=["price_actual_lag1", "price_actual_lag24", "price_actual_lag168"])

# ステップ 3：df_test にラグ追加（train の末尾を参照）
train_price = df_train.set_index("time")["price_actual"]

# 時間差からラグ生成（NaNがあっても dropna しない！）
for lag in [1, 24, 168]:
    df_test[f"price_actual_lag{lag}"] = df_test["time"].apply(
        lambda t: train_price.get(t - pd.Timedelta(hours=lag), np.nan)
    )

# ※ここでは df_test.dropna() しない → 提出用行数は保たれる

# モデルで使う test データだけ mask で抽出（あとで予測に使う）
test_mask = df_test[["price_actual_lag1", "price_actual_lag24", "price_actual_lag168"]].notna().all(axis=1)

# ✅ 表示確認（trainのみ）
display(df_train[["price_actual","price_actual_lag1","price_actual_lag24"]])
# Out:
#        price_actual  price_actual_lag1  price_actual_lag24
# 168           67.70              73.14               73.73
# 169           61.05              67.70               70.99
# 170           59.61              61.05               68.30
# 171           58.65              59.61               64.22
# 172           58.40              58.65               63.53
# ...             ...                ...                 ...
# 26275         39.90              35.37               62.92
# 26276         39.54              39.90               62.10
# 26277         32.90              39.54               60.09
# 26278         23.85              32.90               55.85
# 26279         23.95              23.85               53.57
#
# [26112 rows x 3 columns]

# %%
# ---------------------------totalload_actualのラグ特徴量---------------------------
lags = [1,24,168]
lag_targets = ["total_load_actual"]
for df in (df_train,df_test):
  for col in lag_targets:
    for i in lags:
      new_col = f"{col}_lag{i}"
      df[new_col] = df[col].shift(1)
      print(new_col)
df_train.head()
# Out:
# total_load_actual_lag1
# total_load_actual_lag24
# total_load_actual_lag168
# total_load_actual_lag1
# total_load_actual_lag24
# total_load_actual_lag168
#                          time  generation_biomass  \
# 168 2015-01-08 23:00:00+00:00               546.0
# 169 2015-01-09 00:00:00+00:00               516.0
# 170 2015-01-09 01:00:00+00:00               508.0
# 171 2015-01-09 02:00:00+00:00               509.0
# 172 2015-01-09 03:00:00+00:00               518.0
#
#      generation_fossil_brown_coal/lignite  generation_fossil_gas  \
# 168                                 571.0                 4178.0
# 169                                 566.0                 3912.0
# 170                                 455.0                 3718.0
# 171                                 369.0                 3768.0
# 172                                 367.0                 3707.0
#
#      generation_fossil_hard_coal  generation_fossil_oil  \
# 168                       7280.0                  383.0
# 169                       6774.0                  370.0
# 170                       6349.0                  372.0
# 171                       6078.0                  373.0
# 172                       5984.0                  373.0
#
#      generation_hydro_pumped_storage_consumption  \
# 168                                        398.0
# 169                                        392.0
# 170                                        956.0
# 171                                       1088.0
# 172                                       1027.0
#
#      generation_hydro_run_of_river_and_poundage  \
# 168                                       658.0
# 169                                       628.0
# 170                                       631.0
# 171                                       634.0
# 172                                       636.0
#
#      generation_hydro_water_reservoir  generation_nuclear  ...  \
# 168                             831.0              6741.0  ...
# 169                             942.0              6741.0  ...
# 170                             882.0              6742.0  ...
# 171                             934.0              6743.0  ...
# 172                             799.0              6744.0  ...
#
#      fossil_share_diff1  renewable_share_diff1  fossil_share_dev7d  \
# 168           -0.028834              -0.006481            0.130535
# 169           -0.010630               0.005780            0.119633
# 170           -0.014436               0.020688            0.104982
# 171           -0.001506               0.008764            0.103165
# 172            0.001479              -0.005488            0.104254
#
#      renewable_share_dev7d  price_actual_lag1  price_actual_lag24  \
# 168              -0.104604              73.14               73.73
# 169              -0.098472              67.70               70.99
# 170              -0.077546              61.05               68.30
# 171              -0.068615              59.61               64.22
# 172              -0.073815              58.65               63.53
#
#      price_actual_lag168  total_load_actual_lag1  total_load_actual_lag24  \
# 168                64.02                     NaN                      NaN
# 169                58.46                 26788.0                  26788.0
# 170                54.70                 25146.0                  25146.0
# 171                54.91                 23889.0                  23889.0
# 172                53.07                 23046.0                  23046.0
#
#      total_load_actual_lag168
# 168                       NaN
# 169                   26788.0
# 170                   25146.0
# 171                   23889.0
# 172                   23046.0
#
# [5 rows x 123 columns]

# %% [markdown]
# ## データ分割＆モデル実装

# %%
# 特徴量の整理

base_features = [
    'generation_fossil_gas',
    'generation_fossil_hard_coal',
    'generation_fossil_oil',
    'generation_hydro_pumped_storage_consumption',
    'generation_hydro_run_of_river_and_poundage',
    'generation_hydro_water_reservoir',
    'generation_other_renewable',
    'total_load_actual',
]

add_features = [
    "generation_biomass",
    "generation_fossil_brown_coal/lignite",
    "valencia_wind_speed",
    "madrid_wind_speed",
    "bilbao_pressure",
    "bilbao_wind_speed",
    "bilbao_clouds_all",
    "barcelona_pressure",
    "barcelona_wind_speed",
    "seville_pressure",
    "seville_wind_deg",

    "season",
    "time_of_day",
    "is_weekend",
    "is_holiday",
    "is_long_wend",
    'generation_sum',
    "fossil_share",
    "renewable_share",
    "time_of_day_only_night",
    "valencia_temp_diff",
    "season_isweekend",
    "time_of_day_isweekend",
    "temp_dev",
    "fossil_share_diff1",
    "renewable_share_diff1",
    "fossil_share_dev7d",
    "renewable_share_dev7d",
    #"price_actual_lag1",
    #"price_actual_lag24",
    #"price_actual_lag168",
    "total_load_actual_lag1",
    "total_load_actual_lag24",
    "total_load_actual_lag168",
]
"""
add_features = [
    "total_load_actual_lag1",
    "total_load_actual_lag24",
    "total_load_actual_lag168",
]
"""
features = base_features + add_features

# %%
# ------------------------------------------------------------
# CatBoost
# ------------------------------------------------------------
params_cb = dict(
    iterations       = 5000,
    learning_rate    = 0.05,
    depth            = 8,
    loss_function    = "RMSE",
    eval_metric      = "RMSE",
    random_seed      = 42,
    od_type          = "Iter",
    od_wait          = 200,   # early stopping
    verbose          = 200
)

mask_tr = df_train["time"].between("2015-01-01", "2017-09-30")
mask_va = df_train["time"].between("2017-10-01", "2017-12-31")

X_tr, y_tr = df_train.loc[mask_tr, features], df_train.loc[mask_tr, "price_actual"]
X_va, y_va = df_train.loc[mask_va, features], df_train.loc[mask_va, "price_actual"]

#train_pool = Pool(X_tr, y_tr, cat_features=[features.index(c) for c in cat_cols])
#valid_pool = Pool(X_va, y_va, cat_features=[features.index(c) for c in cat_cols])

train_pool = Pool(X_tr, y_tr)
valid_pool = Pool(X_va, y_va)

model_cb = CatBoostRegressor(**params_cb)
model_cb.fit(train_pool, eval_set=valid_pool, use_best_model=True)

pred_va = model_cb.predict(valid_pool)
mse_cb = mean_squared_error(y_va, pred_va)
rmse_cb = np.sqrt(mse_cb)

print("CatBoost Pattern-3  RMSE:", rmse_cb)
# Out:
# 0:	learn: 13.7971119	test: 15.0696863	best: 15.0696863 (0)	total: 140ms	remaining: 11m 41s
# 200:	learn: 5.1529443	test: 8.4821563	best: 8.4818638 (199)	total: 15.3s	remaining: 6m 5s
# 400:	learn: 4.0743649	test: 8.3050822	best: 8.3026171 (362)	total: 22.3s	remaining: 4m 16s
# 600:	learn: 3.5035016	test: 8.2660900	best: 8.2657995 (599)	total: 29s	remaining: 3m 32s
# 800:	learn: 3.0876620	test: 8.2860188	best: 8.2613890 (652)	total: 34.6s	remaining: 3m 1s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 8.261388968
# bestIteration = 652
#
# Shrink model to first 653 iterations.
# CatBoost Pattern-3  RMSE: 8.261388940323398

# %%
#---------------------------複数回す--------------------------------
mask_tr = df_train["time"].between("2015-01-01", "2017-09-30")
mask_va = df_train["time"].between("2017-10-01", "2017-12-31")


from copy import deepcopy
results = []

for add in [None] + add_features:
    if add is None:
        current_features = deepcopy(base_features)
        tag = "Base only"
    else:
        current_features = deepcopy(base_features) + [add]
        tag = f"Add {add}"

    print(f"\n▶ Running with: {tag}")


    X_tr, y_tr = df_train.loc[mask_tr, current_features], df_train.loc[mask_tr, "price_actual"]
    X_va, y_va = df_train.loc[mask_va, current_features], df_train.loc[mask_va, "price_actual"]

    train_pool = Pool(X_tr, y_tr)
    valid_pool = Pool(X_va, y_va)

    model_cb = CatBoostRegressor(**params_cb)
    model_cb.fit(train_pool, eval_set=valid_pool, use_best_model=True)

    pred_va = model_cb.predict(valid_pool)
    mse_cb = mean_squared_error(y_va, pred_va)
    rmse_cb = np.sqrt(mse_cb)

    print("CatBoost Pattern-3  RMSE:", rmse_cb)


    results.append({
        "tag": tag,
        "features": current_features,
        "rmse": rmse_cb
    })
# Out:
# ▶ Running with: Base only
# 0:	learn: 14.0065225	test: 15.2109665	best: 15.2109665 (0)	total: 37.7ms	remaining: 3m 8s
# 200:	learn: 9.3353224	test: 13.8304127	best: 13.4464215 (48)	total: 4.76s	remaining: 1m 53s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.44642148
# bestIteration = 48
#
# Shrink model to first 49 iterations.
# CatBoost Pattern-3  RMSE: 13.446421457255964
#
# ▶ Running with: Add generation_biomass
# 0:	learn: 13.9894900	test: 15.2538772	best: 15.2538772 (0)	total: 14.3ms	remaining: 1m 11s
# 200:	learn: 8.9605278	test: 14.1484257	best: 13.6881263 (57)	total: 2.35s	remaining: 56.1s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.68812628
# bestIteration = 57
#
# Shrink model to first 58 iterations.
# CatBoost Pattern-3  RMSE: 13.688126254786338
#
# ▶ Running with: Add generation_fossil_brown_coal/lignite
# 0:	learn: 14.0020099	test: 15.2123308	best: 15.2123308 (0)	total: 11.8ms	remaining: 58.8s
# 200:	learn: 9.1331874	test: 13.8007518	best: 13.4845808 (52)	total: 2.35s	remaining: 56.1s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.48458081
# bestIteration = 52
#
# Shrink model to first 53 iterations.
# CatBoost Pattern-3  RMSE: 13.484580780986358
#
# ▶ Running with: Add valencia_wind_speed
# 0:	learn: 13.9915264	test: 15.1851833	best: 15.1851833 (0)	total: 16.1ms	remaining: 1m 20s
# 200:	learn: 9.0547458	test: 13.3532113	best: 13.1514137 (84)	total: 2.25s	remaining: 53.8s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.15141369
# bestIteration = 84
#
# Shrink model to first 85 iterations.
# CatBoost Pattern-3  RMSE: 13.151413659788785
#
# ▶ Running with: Add madrid_wind_speed
# 0:	learn: 13.9881011	test: 15.1967505	best: 15.1967505 (0)	total: 32.4ms	remaining: 2m 42s
# 200:	learn: 8.8875956	test: 12.6220469	best: 12.5770443 (110)	total: 4.02s	remaining: 1m 35s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 12.57704429
# bestIteration = 110
#
# Shrink model to first 111 iterations.
# CatBoost Pattern-3  RMSE: 12.577044258443149
#
# ▶ Running with: Add bilbao_pressure
# 0:	learn: 13.9923992	test: 15.2085180	best: 15.2085180 (0)	total: 12ms	remaining: 59.8s
# 200:	learn: 8.7263247	test: 12.7113460	best: 12.5082073 (78)	total: 2.17s	remaining: 51.7s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 12.50820731
# bestIteration = 78
#
# Shrink model to first 79 iterations.
# CatBoost Pattern-3  RMSE: 12.508207272131285
#
# ▶ Running with: Add bilbao_wind_speed
# 0:	learn: 13.9872433	test: 15.1892071	best: 15.1892071 (0)	total: 11.3ms	remaining: 56.6s
# 200:	learn: 9.0143396	test: 13.4645722	best: 13.2812358 (93)	total: 2.2s	remaining: 52.6s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.28123576
# bestIteration = 93
#
# Shrink model to first 94 iterations.
# CatBoost Pattern-3  RMSE: 13.281235725930717
#
# ▶ Running with: Add bilbao_clouds_all
# 0:	learn: 14.0033452	test: 15.2309536	best: 15.2309536 (0)	total: 11.7ms	remaining: 58.7s
# 200:	learn: 9.0717382	test: 13.7510181	best: 13.4198250 (55)	total: 3.85s	remaining: 1m 31s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.41982499
# bestIteration = 55
#
# Shrink model to first 56 iterations.
# CatBoost Pattern-3  RMSE: 13.41982495587226
#
# ▶ Running with: Add barcelona_pressure
# 0:	learn: 13.9723767	test: 15.2223904	best: 15.2223904 (0)	total: 11.4ms	remaining: 56.8s
# 200:	learn: 8.5750905	test: 12.5764654	best: 12.5568155 (192)	total: 2.19s	remaining: 52.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 12.55681547
# bestIteration = 192
#
# Shrink model to first 193 iterations.
# CatBoost Pattern-3  RMSE: 12.556815433970932
#
# ▶ Running with: Add barcelona_wind_speed
# 0:	learn: 13.9952122	test: 15.1966993	best: 15.1966993 (0)	total: 11ms	remaining: 54.9s
# 200:	learn: 9.1401310	test: 13.4966830	best: 13.2312209 (61)	total: 2.23s	remaining: 53.1s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.23122092
# bestIteration = 61
#
# Shrink model to first 62 iterations.
# CatBoost Pattern-3  RMSE: 13.231220892567924
#
# ▶ Running with: Add seville_pressure
# 0:	learn: 13.9979350	test: 15.2205233	best: 15.2205233 (0)	total: 11.4ms	remaining: 56.9s
# 200:	learn: 8.9676485	test: 12.9701086	best: 12.8659082 (112)	total: 2.19s	remaining: 52.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 12.86590822
# bestIteration = 112
#
# Shrink model to first 113 iterations.
# CatBoost Pattern-3  RMSE: 12.865908207687596
#
# ▶ Running with: Add seville_wind_deg
# 0:	learn: 13.9991226	test: 15.1941259	best: 15.1941259 (0)	total: 41.5ms	remaining: 3m 27s
# 200:	learn: 9.1456743	test: 12.8858995	best: 12.7791979 (87)	total: 3.26s	remaining: 1m 17s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 12.77919795
# bestIteration = 87
#
# Shrink model to first 88 iterations.
# CatBoost Pattern-3  RMSE: 12.779197923480762
#
# ▶ Running with: Add season
# 0:	learn: 13.9373103	test: 15.2641061	best: 15.2641061 (0)	total: 14.2ms	remaining: 1m 10s
# 200:	learn: 8.0582324	test: 11.4398214	best: 11.4092478 (128)	total: 2.27s	remaining: 54.3s
# 400:	learn: 7.0225540	test: 11.3858574	best: 11.3786658 (253)	total: 4.52s	remaining: 51.8s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 11.37866583
# bestIteration = 253
#
# Shrink model to first 254 iterations.
# CatBoost Pattern-3  RMSE: 11.378665827193625
#
# ▶ Running with: Add time_of_day
# 0:	learn: 13.9876848	test: 15.1956857	best: 15.1956857 (0)	total: 11.4ms	remaining: 57.1s
# 200:	learn: 9.0466075	test: 13.3352336	best: 13.0693574 (71)	total: 2.87s	remaining: 1m 8s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.0693574
# bestIteration = 71
#
# Shrink model to first 72 iterations.
# CatBoost Pattern-3  RMSE: 13.069357376549386
#
# ▶ Running with: Add is_weekend
# 0:	learn: 13.9617401	test: 15.1665877	best: 15.1665877 (0)	total: 28.8ms	remaining: 2m 23s
# 200:	learn: 8.7434665	test: 13.3679907	best: 13.1738449 (68)	total: 2.66s	remaining: 1m 3s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.17384487
# bestIteration = 68
#
# Shrink model to first 69 iterations.
# CatBoost Pattern-3  RMSE: 13.173844838965591
#
# ▶ Running with: Add is_holiday
# 0:	learn: 14.0027379	test: 15.2090390	best: 15.2090390 (0)	total: 11ms	remaining: 54.9s
# 200:	learn: 9.3114738	test: 13.7719535	best: 13.4972653 (61)	total: 2.2s	remaining: 52.5s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.4972653
# bestIteration = 61
#
# Shrink model to first 62 iterations.
# CatBoost Pattern-3  RMSE: 13.497265271404787
#
# ▶ Running with: Add is_long_wend
# 0:	learn: 14.0027379	test: 15.2090390	best: 15.2090390 (0)	total: 10.6ms	remaining: 53.2s
# 200:	learn: 9.3166993	test: 13.8332818	best: 13.5683326 (51)	total: 2.19s	remaining: 52.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.56833255
# bestIteration = 51
#
# Shrink model to first 52 iterations.
# CatBoost Pattern-3  RMSE: 13.568332522852838
#
# ▶ Running with: Add generation_sum
# 0:	learn: 13.9997558	test: 15.1919899	best: 15.1919899 (0)	total: 14.3ms	remaining: 1m 11s
# 200:	learn: 9.2952290	test: 13.7588383	best: 13.4010080 (49)	total: 3.53s	remaining: 1m 24s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.40100804
# bestIteration = 49
#
# Shrink model to first 50 iterations.
# CatBoost Pattern-3  RMSE: 13.401008014895767
#
# ▶ Running with: Add fossil_share
# 0:	learn: 14.0027379	test: 15.2090390	best: 15.2090390 (0)	total: 27.4ms	remaining: 2m 16s
# 200:	learn: 9.3622926	test: 14.0220430	best: 13.6086471 (50)	total: 2.58s	remaining: 1m 1s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.60864714
# bestIteration = 50
#
# Shrink model to first 51 iterations.
# CatBoost Pattern-3  RMSE: 13.60864711032088
#
# ▶ Running with: Add renewable_share
# 0:	learn: 14.0044833	test: 15.2056604	best: 15.2056604 (0)	total: 11.8ms	remaining: 58.9s
# 200:	learn: 9.3182214	test: 13.8149070	best: 13.4789871 (48)	total: 2.36s	remaining: 56.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.47898713
# bestIteration = 48
#
# Shrink model to first 49 iterations.
# CatBoost Pattern-3  RMSE: 13.478987098834295
#
# ▶ Running with: Add time_of_day_only_night
# 0:	learn: 13.9876848	test: 15.1956857	best: 15.1956857 (0)	total: 13.5ms	remaining: 1m 7s
# 200:	learn: 9.0466075	test: 13.3352336	best: 13.0693574 (71)	total: 2.19s	remaining: 52.3s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.0693574
# bestIteration = 71
#
# Shrink model to first 72 iterations.
# CatBoost Pattern-3  RMSE: 13.069357376549386
#
# ▶ Running with: Add valencia_temp_diff
# 0:	learn: 13.9525254	test: 15.1696230	best: 15.1696230 (0)	total: 16.4ms	remaining: 1m 21s
# 200:	learn: 8.8212962	test: 13.1102448	best: 12.6127024 (59)	total: 4.27s	remaining: 1m 41s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 12.6127024
# bestIteration = 59
#
# Shrink model to first 60 iterations.
# CatBoost Pattern-3  RMSE: 12.612702369712519
#
# ▶ Running with: Add season_isweekend
# 0:	learn: 13.9617401	test: 15.1665877	best: 15.1665877 (0)	total: 14.7ms	remaining: 1m 13s
# 200:	learn: 8.5718418	test: 12.9634260	best: 12.8795111 (107)	total: 2.18s	remaining: 52.1s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 12.87951113
# bestIteration = 107
#
# Shrink model to first 108 iterations.
# CatBoost Pattern-3  RMSE: 12.879511105971257
#
# ▶ Running with: Add time_of_day_isweekend
# 0:	learn: 13.9617401	test: 15.1665877	best: 15.1665877 (0)	total: 10.8ms	remaining: 53.9s
# 200:	learn: 8.7081200	test: 13.3276565	best: 13.0670638 (47)	total: 2.19s	remaining: 52.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.06706375
# bestIteration = 47
#
# Shrink model to first 48 iterations.
# CatBoost Pattern-3  RMSE: 13.067063723448634
#
# ▶ Running with: Add temp_dev
# 0:	learn: 13.9841022	test: 15.1636761	best: 15.1636761 (0)	total: 14.7ms	remaining: 1m 13s
# 200:	learn: 8.9640362	test: 13.1761520	best: 13.1011740 (129)	total: 2.34s	remaining: 56s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.10117397
# bestIteration = 129
#
# Shrink model to first 130 iterations.
# CatBoost Pattern-3  RMSE: 13.101173964315063
#
# ▶ Running with: Add fossil_share_diff1
# 0:	learn: 14.0027379	test: 15.2090390	best: 15.2090390 (0)	total: 36.6ms	remaining: 3m 3s
# 200:	learn: 9.3702408	test: 13.8283222	best: 13.5189338 (59)	total: 3.39s	remaining: 1m 20s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.51893375
# bestIteration = 59
#
# Shrink model to first 60 iterations.
# CatBoost Pattern-3  RMSE: 13.518933719930983
#
# ▶ Running with: Add renewable_share_diff1
# 0:	learn: 14.0027379	test: 15.2090390	best: 15.2090390 (0)	total: 12.1ms	remaining: 1m
# 200:	learn: 9.3274136	test: 13.8160515	best: 13.5252297 (51)	total: 2.35s	remaining: 56s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.5252297
# bestIteration = 51
#
# Shrink model to first 52 iterations.
# CatBoost Pattern-3  RMSE: 13.5252296729106
#
# ▶ Running with: Add fossil_share_dev7d
# 0:	learn: 13.9929188	test: 15.2384162	best: 15.2384162 (0)	total: 12ms	remaining: 59.9s
# 200:	learn: 8.7366884	test: 13.1000434	best: 12.9815873 (108)	total: 2.39s	remaining: 57s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 12.98158729
# bestIteration = 108
#
# Shrink model to first 109 iterations.
# CatBoost Pattern-3  RMSE: 12.981587265800185
#
# ▶ Running with: Add renewable_share_dev7d
# 0:	learn: 13.9889009	test: 15.1960778	best: 15.1960778 (0)	total: 11.4ms	remaining: 56.8s
# 200:	learn: 8.9456883	test: 13.1999606	best: 12.9033604 (93)	total: 4.42s	remaining: 1m 45s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 12.90336042
# bestIteration = 93
#
# Shrink model to first 94 iterations.
# CatBoost Pattern-3  RMSE: 12.903360389249817
#
# ▶ Running with: Add price_actual_lag1
# 0:	learn: 13.6067476	test: 14.7105958	best: 14.7105958 (0)	total: 12.2ms	remaining: 1m 1s
# 200:	learn: 3.3938530	test: 4.4171643	best: 4.4169073 (198)	total: 2.35s	remaining: 56.2s
# 400:	learn: 3.1985191	test: 4.4185048	best: 4.4155872 (206)	total: 4.74s	remaining: 54.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 4.415587154
# bestIteration = 206
#
# Shrink model to first 207 iterations.
# CatBoost Pattern-3  RMSE: 4.4155870869566645
#
# ▶ Running with: Add price_actual_lag24
# 0:	learn: 13.7786528	test: 14.8631385	best: 14.8631385 (0)	total: 11.4ms	remaining: 57.2s
# 200:	learn: 6.7509436	test: 8.2539295	best: 8.2260311 (74)	total: 2.25s	remaining: 53.6s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 8.226031141
# bestIteration = 74
#
# Shrink model to first 75 iterations.
# CatBoost Pattern-3  RMSE: 8.226031127155764
#
# ▶ Running with: Add price_actual_lag168
# 0:	learn: 13.7804760	test: 14.9352389	best: 14.9352389 (0)	total: 12ms	remaining: 59.8s
# 200:	learn: 6.4893666	test: 9.0378636	best: 8.9000582 (63)	total: 4.15s	remaining: 1m 39s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 8.900058241
# bestIteration = 63
#
# Shrink model to first 64 iterations.
# CatBoost Pattern-3  RMSE: 8.900058231397184
#
# ▶ Running with: Add total_load_actual_lag1
# 0:	learn: 14.0014642	test: 15.2067624	best: 15.2067624 (0)	total: 11.6ms	remaining: 58.2s
# 200:	learn: 9.3413941	test: 13.7763869	best: 13.5398379 (88)	total: 2.34s	remaining: 56s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.53983785
# bestIteration = 88
#
# Shrink model to first 89 iterations.
# CatBoost Pattern-3  RMSE: 13.539837822417487
#
# ▶ Running with: Add total_load_actual_lag24
# 0:	learn: 14.0014642	test: 15.2067624	best: 15.2067624 (0)	total: 11.7ms	remaining: 58.4s
# 200:	learn: 9.3413941	test: 13.7763869	best: 13.5398379 (88)	total: 4.74s	remaining: 1m 53s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.53983785
# bestIteration = 88
#
# Shrink model to first 89 iterations.
# CatBoost Pattern-3  RMSE: 13.539837822417487
#
# ▶ Running with: Add total_load_actual_lag168
# 0:	learn: 14.0014642	test: 15.2067624	best: 15.2067624 (0)	total: 11.8ms	remaining: 59s
# 200:	learn: 9.3413941	test: 13.7763869	best: 13.5398379 (88)	total: 4.62s	remaining: 1m 50s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 13.53983785
# bestIteration = 88
#
# Shrink model to first 89 iterations.
# CatBoost Pattern-3  RMSE: 13.539837822417487
# [{'tag': 'Base only',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual'],
#   'rmse': np.float64(13.446421457255964)},
#  {'tag': 'Add generation_biomass',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'generation_biomass'],
#   'rmse': np.float64(13.688126254786338)},
#  {'tag': 'Add generation_fossil_brown_coal/lignite',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'generation_fossil_brown_coal/lignite'],
#   'rmse': np.float64(13.484580780986358)},
#  {'tag': 'Add valencia_wind_speed',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'valencia_wind_speed'],
#   'rmse': np.float64(13.151413659788785)},
#  {'tag': 'Add madrid_wind_speed',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'madrid_wind_speed'],
#   'rmse': np.float64(12.577044258443149)},
#  {'tag': 'Add bilbao_pressure',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'bilbao_pressure'],
#   'rmse': np.float64(12.508207272131285)},
#  {'tag': 'Add bilbao_wind_speed',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'bilbao_wind_speed'],
#   'rmse': np.float64(13.281235725930717)},
#  {'tag': 'Add bilbao_clouds_all',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'bilbao_clouds_all'],
#   'rmse': np.float64(13.41982495587226)},
#  {'tag': 'Add barcelona_pressure',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'barcelona_pressure'],
#   'rmse': np.float64(12.556815433970932)},
#  {'tag': 'Add barcelona_wind_speed',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'barcelona_wind_speed'],
#   'rmse': np.float64(13.231220892567924)},
#  {'tag': 'Add seville_pressure',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'seville_pressure'],
#   'rmse': np.float64(12.865908207687596)},
#  {'tag': 'Add seville_wind_deg',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'seville_wind_deg'],
#   'rmse': np.float64(12.779197923480762)},
#  {'tag': 'Add season',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'season'],
#   'rmse': np.float64(11.378665827193625)},
#  {'tag': 'Add time_of_day',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'time_of_day'],
#   'rmse': np.float64(13.069357376549386)},
#  {'tag': 'Add is_weekend',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'is_weekend'],
#   'rmse': np.float64(13.173844838965591)},
#  {'tag': 'Add is_holiday',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'is_holiday'],
#   'rmse': np.float64(13.497265271404787)},
#  {'tag': 'Add is_long_wend',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'is_long_wend'],
#   'rmse': np.float64(13.568332522852838)},
#  {'tag': 'Add generation_sum',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'generation_sum'],
#   'rmse': np.float64(13.401008014895767)},
#  {'tag': 'Add fossil_share',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'fossil_share'],
#   'rmse': np.float64(13.60864711032088)},
#  {'tag': 'Add renewable_share',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'renewable_share'],
#   'rmse': np.float64(13.478987098834295)},
#  {'tag': 'Add time_of_day_only_night',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'time_of_day_only_night'],
#   'rmse': np.float64(13.069357376549386)},
#  {'tag': 'Add valencia_temp_diff',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'valencia_temp_diff'],
#   'rmse': np.float64(12.612702369712519)},
#  {'tag': 'Add season_isweekend',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'season_isweekend'],
#   'rmse': np.float64(12.879511105971257)},
#  {'tag': 'Add time_of_day_isweekend',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'time_of_day_isweekend'],
#   'rmse': np.float64(13.067063723448634)},
#  {'tag': 'Add temp_dev',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'temp_dev'],
#   'rmse': np.float64(13.101173964315063)},
#  {'tag': 'Add fossil_share_diff1',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'fossil_share_diff1'],
#   'rmse': np.float64(13.518933719930983)},
#  {'tag': 'Add renewable_share_diff1',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'renewable_share_diff1'],
#   'rmse': np.float64(13.5252296729106)},
#  {'tag': 'Add fossil_share_dev7d',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'fossil_share_dev7d'],
#   'rmse': np.float64(12.981587265800185)},
#  {'tag': 'Add renewable_share_dev7d',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'renewable_share_dev7d'],
#   'rmse': np.float64(12.903360389249817)},
#  {'tag': 'Add price_actual_lag1',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'price_actual_lag1'],
#   'rmse': np.float64(4.4155870869566645)},
#  {'tag': 'Add price_actual_lag24',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'price_actual_lag24'],
#   'rmse': np.float64(8.226031127155764)},
#  {'tag': 'Add price_actual_lag168',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'price_actual_lag168'],
#   'rmse': np.float64(8.900058231397184)},
#  {'tag': 'Add total_load_actual_lag1',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'total_load_actual_lag1'],
#   'rmse': np.float64(13.539837822417487)},
#  {'tag': 'Add total_load_actual_lag24',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'total_load_actual_lag24'],
#   'rmse': np.float64(13.539837822417487)},
#  {'tag': 'Add total_load_actual_lag168',
#   'features': ['generation_fossil_gas',
#    'generation_fossil_hard_coal',
#    'generation_fossil_oil',
#    'generation_hydro_pumped_storage_consumption',
#    'generation_hydro_run_of_river_and_poundage',
#    'generation_hydro_water_reservoir',
#    'generation_other_renewable',
#    'total_load_actual',
#    'total_load_actual_lag168'],
#   'rmse': np.float64(13.539837822417487)}]

# %%
df_display = pd.DataFrame([{'tag': item['tag'], 'rmse': item['rmse']} for item in results])
df_display
# Out:
#                                          tag       rmse
# 0                                  Base only  13.446421
# 1                     Add generation_biomass  13.688126
# 2   Add generation_fossil_brown_coal/lignite  13.484581
# 3                    Add valencia_wind_speed  13.151414
# 4                      Add madrid_wind_speed  12.577044
# 5                        Add bilbao_pressure  12.508207
# 6                      Add bilbao_wind_speed  13.281236
# 7                      Add bilbao_clouds_all  13.419825
# 8                     Add barcelona_pressure  12.556815
# 9                   Add barcelona_wind_speed  13.231221
# 10                      Add seville_pressure  12.865908
# 11                      Add seville_wind_deg  12.779198
# 12                                Add season  11.378666
# 13                           Add time_of_day  13.069357
# 14                            Add is_weekend  13.173845
# 15                            Add is_holiday  13.497265
# 16                          Add is_long_wend  13.568333
# 17                        Add generation_sum  13.401008
# 18                          Add fossil_share  13.608647
# 19                       Add renewable_share  13.478987
# 20                Add time_of_day_only_night  13.069357
# 21                    Add valencia_temp_diff  12.612702
# 22                      Add season_isweekend  12.879511
# 23                 Add time_of_day_isweekend  13.067064
# 24                              Add temp_dev  13.101174
# 25                    Add fossil_share_diff1  13.518934
# 26                 Add renewable_share_diff1  13.525230
# 27                    Add fossil_share_dev7d  12.981587
# 28                 Add renewable_share_dev7d  12.903360
# 29                     Add price_actual_lag1   4.415587
# 30                    Add price_actual_lag24   8.226031
# 31                   Add price_actual_lag168   8.900058
# 32                Add total_load_actual_lag1  13.539838
# 33               Add total_load_actual_lag24  13.539838
# 34              Add total_load_actual_lag168  13.539838

# %%
# 全データで再学習 → テスト予測
#full_pool = Pool(df_train[features], df_train["price_actual"],cat_features=[features.index(c) for c in cat_cols])

full_pool = Pool(df_train[features], df_train["price_actual"])

model_cb_full = CatBoostRegressor(**params_cb)
model_cb_full.fit(full_pool, verbose=False)

#pred_test = model_cb_full.predict(Pool(df_test[features],cat_features=[features.index(c) for c in cat_cols]))
pred_test = model_cb_full.predict(Pool(df_test[features]))

# %%
# ------------------------------------------------------------
# ファイルをダウンロード
# ------------------------------------------------------------
from datetime import datetime, timedelta, timezone
from zoneinfo import ZoneInfo   # 3.9 から標準搭載

# ① まずは “現在の UTC 時刻” を取得
utc_now = datetime.now(timezone.utc)

# ② UTC → JST(+9) に変換して、日付部分だけ取り出す
today = utc_now.astimezone(ZoneInfo("Asia/Tokyo")).date()

df_sub = pd.read_csv(file_path + 'sample_submit.csv',header=None)

submission = pd.DataFrame({
    'time':df_sub.iloc[:, 0] ,
    'pred':pred_test
})

filename = input("ファイル名を入力してください")
submission.to_csv(f'submission_{today}_{filename}.csv', index=False, header=False)
print(f'✅ Submission file saved as submission_{today}_{filename}.csv')
# Out:
# ファイル名を入力してくださいcatboost_v4
# ✅ Submission file saved as submission_2025-06-24_catboost_v4.csv

# %% [markdown]
# ## ラグ逐次変化のトライ

# %%
# ------------------------------------------------------------
# 逐次予測 (recursive forecasting) ― price_actual_lag1 を安全利用
# ------------------------------------------------------------
# 前提：df_train / df_test / features / model_full が既に定義済み
#       features には "price_actual_lag1" を含めておく
#       （lag24 / lag168 を使うなら同様に列名を追加）


# 1) 時系列順で test を並べ替え
df_test = df_test.sort_values("time").reset_index(drop=True)

# 2) ラグ用バッファを初期化
last_price = df_train.iloc[-1]["price_actual"]          # ← lag1 用
from collections import deque
buffer_24  = deque(df_train["price_actual"].tail(24).tolist(),  maxlen=24)
buffer_168 = deque(df_train["price_actual"].tail(168).tolist(), maxlen=168)


# 3) 逐次ループで 1 行ずつ予測 → バッファ更新
pred_test = []

for _, row in df_test.iterrows():
    # --- ラグを上書き ---
    row_feats = row.copy()
    row_feats["price_actual_lag1"] = last_price
    # row_feats["price_actual_lag24"]  = buffer_24[-1]   # ← 使うならアンコメント
    # row_feats["price_actual_lag168"] = buffer_168[-1]  # ← 使うならアンコメント

    # --- 1 行 DataFrame 化して数値型へ ---
    X_row = row_feats[features].astype(float).to_frame().T

    # --- 予測 ---
    y_hat = model_cb_full.predict(X_row)[0]

    pred_test.append(y_hat)

    # --- バッファ更新 ---
    last_price = y_hat
    buffer_24.append(y_hat)
    buffer_168.append(y_hat)

# %%
# 4) 提出ファイル作成

df_sub = pd.read_csv(file_path + 'sample_submit.csv',header=None)

submission = pd.DataFrame({
    'time':df_sub.iloc[:, 0] ,
    "pred": pred_test                 # 逐次予測した 8760 個
})
submission.to_csv("submission_recursive.csv", index=False, header=False)
